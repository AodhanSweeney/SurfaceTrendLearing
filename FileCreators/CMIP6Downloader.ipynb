# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr
import xesmf as xe
import cartopy
import dask
from tqdm.autonotebook import tqdm  # Fancy progress bars for our loops!
import intake
import fsspec

# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 6
# %config InlineBackend.figure_format = 'retina'

df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df
# Out:
# /home/disk/p/aodhan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#        activity_id       institution_id      source_id       experiment_id  \
# 0       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 1       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 2       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 3       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# 4       HighResMIP                 CMCC   CMCC-CM2-HR4  highresSST-present
# ...            ...                  ...            ...                 ...
# 523769        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# 523770        CMIP  EC-Earth-Consortium  EC-Earth3-Veg          historical
# ...

# %%
df_tvars = df.query("activity_id=='CMIP' & table_id == 'Amon' & variable_id == ['tas', 'ts'] & experiment_id == 'historical'")
df_tvars
# Out:
#        activity_id       institution_id      source_id experiment_id  \
# 973           CMIP            NOAA-GFDL      GFDL-ESM4    historical
# 1018          CMIP            NOAA-GFDL      GFDL-ESM4    historical
# 1194          CMIP            NOAA-GFDL      GFDL-ESM4    historical
# 1766          CMIP            NOAA-GFDL      GFDL-ESM4    historical
# 8074          CMIP            NOAA-GFDL       GFDL-CM4    historical
# ...            ...                  ...            ...           ...
# 523711        CMIP                 CMCC   CMCC-CM2-SR5    historical
# 523712        CMIP                 CMCC   CMCC-CM2-SR5    historical
# 523721        CMIP                 CMCC   CMCC-CM2-SR5    historical
# 523735        CMIP                 CMCC   CMCC-CM2-SR5    historical
# 523769        CMIP  EC-Earth-Consortium  EC-Earth3-Veg    historical
#
#        member_id table_id variable_id grid_label  \
# 973     r3i1p1f1     Amon         tas        gr1
# ...

# %%
# get the path to a specific zarr store (the first one from the dataframe above)
zstore = df_tvars.zstore.values[-1]
print(zstore)

# create a mutable-mapping-style interface to the store
mapper = fsspec.get_mapper(zstore)

# open it using xarray and zarr
ds = xr.open_zarr(mapper, consolidated=True)
# Out:
# gs://cmip6/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3-Veg/historical/r1i1p1f1/Amon/tas/gr/v20211207/
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/fsspec/registry.py in get_filesystem_class(protocol)
#     233         try:
# --> 234             register_implementation(protocol, _import_class(bit["class"]))
#     235         except ImportError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/fsspec/registry.py in _import_class(cls, minv)
#     256         mod, name = cls.rsplit(".", 1)
# --> 257         mod = importlib.import_module(mod)
#     258         return getattr(mod, name)
#
# ~/anaconda3/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# ...

# %%
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7674 dataset(s) from 514818 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
# ...

# %%
query = dict(
    experiment_id=['historical'], # pick the 'historical' forcing experiments
    table_id='Amon',                            # choose to look at atmospheric variables (A) saved at monthly resolution (mon)
    variable_id=['tas', 'ts'],  # choose to look at near-surface air temperature (tas) and surface temp (ts)
)

col_subset = col.search(require_all_on=["source_id"], **query)

"""col_subset.df.groupby("source_id")[
    ["experiment_id", "variable_id", "table_id", 'member_id']
].nunique()"""

# get the path to a specific zarr store (the first one from the dataframe above)
zstore = col_subset.zstore.values[-1]
print(zstore)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/intake_esm/core.py in __getitem__(self, key)
#     467         try:
# --> 468             return self._entries[key]
#     469         except KeyError:
#
# KeyError: 'zstore'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/intake/catalog/base.py in __getattr__(self, item)
#     390             try:
# --> 391                 return self[item]  # triggers reload_on_change
#     392             except KeyError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/intake_esm/core.py in __getitem__(self, key)
#     498                 return self._entries[key]
# --> 499             raise KeyError(key)
#     500
#
# KeyError: 'zstore'
#
# ...

# %%
col_subset
# Out:
# <p><strong>pangeo-cmip6 catalog with 65 dataset(s) from 1218 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>2</td>
# ...
